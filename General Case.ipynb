# %%
import sympy
from sympy import Derivative, Function, Symbol, symbols, Eq, pi, cos, sin, exp, log, oo
from sympy import Function, dsolve, Derivative, checkodesol
from sympy import fps, Rational
from sympy import pprint, Matrix, eye, zeros
from sympy import Inverse
from utils import *
z = Symbol('z')

# %% [markdown]
# Restate the problem that we want to solve:
#
# $$z^k \frac{d\psi}{dz} = A(z)\psi$$, where $\psi$ is a vector-valued function and $A(z)$ as a given matrix-valued function is holomorphic.
#
# At $k = 0$, it is the regular case, we just work on C and find the solution easily.
#
# At $k = 1$, it is the regular singular case
#
# At $k \geq 2$, it is the irregular singular case
#
# Why singular: if we try to solve by putting it into a vector field, we need to divide both sides by $z^k$, in which case, the vector field has a pole of order $k$, causing the flow to be not defined.
#
# Instead of working away from singular point, we consider it on Stok_k(C), the Stokes groupoid, where we have a universal solution $\Phi$
#
# In the case where we could find a fundamental solution $\Psi = \begin{pmatrix} | & | & | \\ \psi_1 & ... & \psi_n \\ | & | & | \end{pmatrix}$ on a simply connected domain $\Omega$, then $\Phi(u, z) = \Psi(t(u, z)) \Psi^{-1}(s(u,z))$, which is defined on $\Omega$ while could be analytically continued to all of Sto_k
#
# In the case where we can't find it directly, we use Formal Gauge transform to simplify the system, and solve it in diagonal version. Then, $\hat{\Phi}(u, z) = \hat{\Psi}(t(u, z)) \hat{\Psi}^{-1}(s(u,z))$ is the formal universal solution on Sto_k, while since $\Phi$ is unique, then this means that $\hat{\Phi}$ is the power series of $\Phi$, so it must be convergent since $\Phi$ is entire.
#
# To do the Gauge transformation, the core idea is to transfer it to the case where $z^k \frac{d\phi}{dz} = (D_0+zD_1+...z^{k-1}D_{k-1})\phi$, where $D_i$ are diagonal, which can be easily solve by agreeing on each degree of $z^k$ on both sides.
#
# In order to solve this problem, we first need to make a change of variables $\phi = \hat{F} \psi$, whereas $\hat{F} = 1+zF_1 + z^2F_2 + ...$
#
#
# In this step, we let $F = (I+zH_1)(I+z^2H_2)...$ where $H_p = ad^{-1}_{A_0}(A_{p}^{OD})$ if $k > 1$ while it is $(ad^{-1}_{A_0} - p)^{-1}(A_{p}^{OD})$ when $k = 1$
#
# After doing this, we make the second Gauge Transform to transform it to the finite case,
#
# which is the transform $K = \exp(-\int{D_k+D_{k+1}z+...})$

# %% [markdown]
# Example1:
#
# $z^2 \psi' = \begin{pmatrix} \cos(z)+1 & \sin(z) \\ -\sin(z) & \cos(z) \end{pmatrix} \psi$
#
# We are working on Sto_2
#
# We trancate the Gauge Transform series up to some given order

# %%
A = Matrix([[cos(z)+1, sin(z)], [-sin(z), cos(z)]])
n = 2
k = 2
order = 10

# %%
K_trunc, F_trunc, Total = get_Gauge_up_to_order(A, k, order)

# %%
K_trunc
# Out:
# Matrix([
# [(exp(z**2*(z**4 + 2520)/15120) + exp(z**4*(z**4 + 6048)/1451520))*exp(z**2*(-3640*z**7 - 315*z**6 + 207360*z**5 - 30240*z**4 - 1524096*z**3 - 1905120*z**2 + 50803200*z - 76204800)/914457600)/2, (exp(z**2*(z**4 + 2520)/15120) - exp(z**4*(z**4 + 6048)/1451520))*exp(z**2*(-3640*z**7 - 315*z**6 + 207360*z**5 - 30240*z**4 - 1524096*z**3 - 1905120*z**2 + 50803200*z - 76204800)/914457600)/2],
# [(exp(z**2*(z**4 + 2520)/15120) - exp(z**4*(z**4 + 6048)/1451520))*exp(z**2*(-3640*z**7 - 315*z**6 + 207360*z**5 - 30240*z**4 - 1524096*z**3 - 1905120*z**2 + 50803200*z - 76204800)/914457600)/2, (exp(z**2*(z**4 + 2520)/15120) + exp(z**4*(z**4 + 6048)/1451520))*exp(z**2*(-3640*z**7 - 315*z**6 + 207360*z**5 - 30240*z**4 - 1524096*z**3 - 1905120*z**2 + 50803200*z - 76204800)/914457600)/2]])

# %%
F_trunc
# Out:
# Matrix([
# [              -z**8/630 + z**6/120 - z**4/6 + 1, z**9/362880 - z**7/5040 + z**5/120 - z**3/6 + z],
# [z**9/362880 - z**7/5040 + z**5/120 - z**3/6 + z,               -z**8/630 + z**6/120 - z**4/6 + 1]])

# %%
Total
# Out:
# Matrix([
# [(z*(exp(z**2*(z**4 + 2520)/15120) - exp(z**4*(z**4 + 6048)/1451520))*(z**8 - 72*z**6 + 3024*z**4 - 60480*z**2 + 362880) - 144*(exp(z**2*(z**4 + 2520)/15120) + exp(z**4*(z**4 + 6048)/1451520))*(4*z**8 - 21*z**6 + 420*z**4 - 2520))*exp(-z**2*(3640*z**7 + 315*z**6 - 207360*z**5 + 30240*z**4 + 1524096*z**3 + 1905120*z**2 - 50803200*z + 76204800)/914457600)/725760, (z*(exp(z**2*(z**4 + 2520)/15120) + exp(z**4*(z**4 + 6048)/1451520))*(z**8 - 72*z**6 + 3024*z**4 - 60480*z**2 + 362880) - 144*(exp(z**2*(z**4 + 2520)/15120) - exp(z**4*(z**4 + 6048)/1451520))*(4*z**8 - 21*z**6 + 420*z**4 - 2520))*exp(-z**2*(3640*z**7 + 315*z**6 - 207360*z**5 + 30240*z**4 + 1524096*z**3 + 1905120*z**2 - 50803200*z + 76204800)/914457600)/725760],
# [(z*(exp(z**2*(z**4 + 2520)/15120) + exp(z**4*(z**4 + 6048)/1451520))*(z**8 - 72*z**6 + 3024*z**4 - 60480*z**2 + 362880) - 144*(exp(z**2*(z**4 + 2520)/15120) - exp(z**4*(z**4 + 6048)/1451520))*(4*z**8 - 21*z**6 + 420*z**4 - 2520))*exp(-z**2*(3640*z**7 + 315*z**6 - 207360*z**5 + 30240*z**4 + 1524096*z**3 + 1905120*z**2 - 50803200*z + 76204800)/914457600)/725760, (z*(exp(z**2*(z**4 + 2520)/15120) - exp(z**4*(z**4 + 6048)/1451520))*(z**8 - 72*z**6 + 3024*z**4 - 60480*z**2 + 362880) - 144*(exp(z**2*(z**4 + 2520)/15120) + exp(z**4*(z**4 + 6048)/1451520))*(4*z**8 - 21*z**6 + 420*z**4 - 2520))*exp(-z**2*(3640*z**7 + 315*z**6 - 207360*z**5 + 30240*z**4 + 1524096*z**3 + 1905120*z**2 - 50803200*z + 76204800)/914457600)/725760]])

# %%
Total_inverse = Total.inverse()

# %%
Total_inverse
# Out:
# Matrix([
# [(362880*z**18*exp(z**6/15120 + z**2/6)*exp(z**8/1451520 + z**4/240) - 181440*z**18*exp(z**6/7560 + z**2/3) - 181440*z**18*exp(z**8/725760 + z**4/120) + 209018880*z**17*exp(z**6/7560 + z**2/3) - 209018880*z**17*exp(z**8/725760 + z**4/120) - 120447129600*z**16*exp(z**6/15120 + z**2/6)*exp(z**8/1451520 + z**4/240) - 60171310080*z**16*exp(z**6/7560 + z**2/3) - 60171310080*z**16*exp(z**8/725760 + z**4/120) - 16146708480*z**15*exp(z**6/7560 + z**2/3) + 16146708480*z**15*exp(z**8/725760 + z**4/120) + 1268222054400*z**14*exp(z**6/15120 + z**2/6)*exp(z**8/1451520 + z**4/240) + 630035159040*z**14*exp(z**6/7560 + z**2/3) + 630035159040*z**14*exp(z**8/725760 + z**4/120) + 733029212160*z**13*exp(z**6/7560 + z**2/3) - 733029212160*z**13*exp(z**8/725760 + z**4/120) - 28803219701760*z**12*exp(z**6/15120 + z**2/6)*exp(z**8/1451520 + z**4/240) - 14199697612800*z**12*exp(z**6/7560 + z**2/3) - 14199697612800*z**12*exp(z**8/725760 + z**4/120) - 17540028334080*z**11*exp(z**6/7560 + z**2/3) + 17540028334080*z**11*exp(z**8/725760 + z**4/120) + 139477462548480*z**10*exp(z**6/15120 + z**2/6)*exp(z**8/1451520 + z**4/240) + 62996618280960*z**10*exp(z**6/7560 + z**2/3) + 62996618280960*z**10*exp(z**8/725760 + z**4/120) + 208452438835200*z**9*exp(z**6/7560 + z**2/3) - 208452438835200*z**9*exp(z**8/725760 + z**4/120) - 1327353495552000*z**8*exp(z**6/15120 + z**2/6)*exp(z**8/1451520 + z**4/240) - 511979205427200*z**8*exp(z**6/7560 + z**2/3) - 511979205427200*z**8*exp(z**8/725760 + z**4/120) - 1716078447820800*z**7*exp(z**6/7560 + z**2/3) + 1716078447820800*z**7*exp(z**8/725760 + z**4/120) + 1327353495552000*z**6*exp(z**6/15120 + z**2/6)*exp(z**8/1451520 + z**4/240) - 1460088845107200*z**6*exp(z**6/7560 + z**2/3) - 1460088845107200*z**6*exp(z**8/725760 + z**4/120) + 7565914924646400*z**5*exp(z**6/7560 + z**2/3) - 7565914924646400*z**5*exp(z**8/725760 + z**4/120) + 15928241946624000*z**4*exp(z**6/7560 + z**2/3) + 15928241946624000*z**4*exp(z**8/725760 + z**4/120) + 7964120973312000*z**3*exp(z**6/7560 + z**2/3) - 7964120973312000*z**3*exp(z**8/725760 + z**4/120) + 47784725839872000*z**2*exp(z**6/15120 + z**2/6)*exp(z**8/1451520 + z**4/240) - 23892362919936000*z**2*exp(z**6/7560 + z**2/3) - 23892362919936000*z**2*exp(z**8/725760 + z**4/120) - 47784725839872000*z*exp(z**6/7560 + z**2/3) + 47784725839872000*z*exp(z**8/725760 + z**4/120) - 47784725839872000*exp(z**6/15120 + z**2/6)*exp(z**8/1451520 + z**4/240) - 23892362919936000*exp(z**6/7560 + z**2/3) - 23892362919936000*exp(z**8/725760 + z**4/120))/(-z**27*exp(z**6/15120 + z**2/6)*exp(z**8/725760 + z**4/120)*exp(-13*z**9/3265920 - z**8/2903040 + z**7/4410 - z**6/30240 - z**5/600 - z**4/480 + z**3/18 - z**2/12) + z**27*exp(z**6/7560 + z**2/3)*exp(z**8/1451520 + z**4/240)*exp(-13*z**9/3265920 - z**8/2903040 + z**7/4410 - z**6/30240 - z**5/600 - z**4/480 + z**3/18 - z**2/12) - 576*z**26*exp(z**6/15120 + z**2/6)*exp(z**8/725760 + z**4/120)*exp(-13*z**9/3265920 - z**8/2903040 + z**7/4410 - z**6/30240 - z**5/600 - z**4/480 + z**3/18 - z**2/12) - 576*z**26*exp(z**6/7560 + z**2/3)*exp(z**8/1451520 + z**4/240)*exp(-13*z**9/3265920 - z**8/2903040 + z**7/4410 - z**6/30240 - z**5/600 - z**4/480 + z**3/18 - z**2/12) + 331992*z**25*exp(z**6/15120 + z**2/6)*exp(z**8/725760 + z**4/120)*exp(-13*z**9/3265920 - z**8/2903040 + z**7/4410 - z**6/30240 - z**5/600 - z**4/480 + z**3/18 - z**2/12) - 331992*z**25*exp(z**6/7560 + z**2/3)*exp(z**8/1451520 + z**4/240)*exp(-13*z**9/3265920 - z**8/2903040 + z**7/4410 - z**6/30240 - z**5/600 - z**4/480 + z**3/18 - z**2/12) + 191188944*z**24*exp(z**6/15120 + z**2/6)*exp(z**8/725760 + z**4/120)*exp(-13*z**9/3265920 - z**8/2903040 + z**7/4410 - z**6/30240 - z**5/600 - z**4/480 + z**3/18 - z**2/12) + 191188944*z**24*exp(z**6/7560 + z**2/3)*exp(z**8/1451520 + z**4/240)*exp(-13*z**9/3265920 - z**8/2903040 + z**7/4410 - z**6/30240 - z**5/600 - z**4/480 + z**3/18 - z**2/12) - 27396144*z**23*exp(z**6/15120 + z**2/6)*exp(z**8/725760 + z**4/120)*exp(-13*z**9/3265920 - z**8/2903040 + z**7/4410 - z**6/3024 ...
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...

# %% [markdown]
# Note that Gauge Transform is a group action, meaning that $F_1[F_2[A]] = (F_1F_2)[A]$ so the inverse Gauge Transform is the Gauge Transform of the inverse Matrix, and composed Gauge Transform is the transform of the product Matrix.

# %% [markdown]
# Finally, the equation is $z^k \psi' = diag(A_0) + diag(A_1)z + ... + diag(A_{k-1})z^{k-1}$

# %%
Psi, Phi = solve_phi(2, A)

# %%
Psi
# Out:
# Matrix([
# [exp(-2/z),         0],
# [        0, exp(-1/z)]])

# %%
Phi
# Out:
# Matrix([
# [exp(2*(1 - exp(-u*z))/z),                      0],
# [                       0, exp((1 - exp(-u*z))/z)]])

# %% [markdown]
# The final solution is $T^{-1}[\Psi]$ (we use $T$ to denote the total Gauge Transform that we applied to simplify the system)
#
# $T^{-1}$ is the Total_inverse that we just found above.

# %% [markdown]
# Example2:
#
# $z^2 \psi' = \begin{pmatrix} z^4+3z^3+1 & z \\ z^2 & z^3+5z^2+7 \end{pmatrix} \psi$
#
# We are working on Sto_2
#
# We trancate the Gauge Transform series up to some given order

# %%
A = Matrix([[z**4+3*z**3+1, z], [z**2, z**3+5*z**2+7]])
n = 2
k = 2
order = 10

# %%
K_trunc, F_trunc, Total = get_Gauge_up_to_order(A, k, order)

# %%
Total
# Out:
# Matrix([
# [                    (36 - z**3)*exp(z**2/72)/36,  -z*exp(z**2/72)/6],
# [(z**3 - 2*(1 - exp(z**2/72))*(z**3 - 36))/(6*z), 2*exp(z**2/72) - 1]])

# %%
Total_inverse = Total.inverse()

# %%
Total_inverse
# Out:
# Matrix([
# [              (-exp(z**2/72) + 2*exp(z**2/36))*exp(-z**2/36),         z/6],
# [(-2*z**3 + z**3*exp(-z**2/72) + 72 - 72*exp(-z**2/72))/(6*z), 1 - z**3/36]])

# %% [markdown]
# Note that Gauge Transform is a group action, meaning that $F_1[F_2[A]] = (F_1F_2)[A]$ so the inverse Gauge Transform is the Gauge Transform of the inverse Matrix, and composed Gauge Transform is the transform of the product Matrix.

# %% [markdown]
# Finally, the equation is $z^k \psi' = diag(A_0) + diag(A_1)z + ... + diag(A_{k-1})z^{k-1}$

# %%
Psi, Phi = solve_phi(2, A)

# %%
Psi
# Out:
# Matrix([
# [exp(-1/z),         0],
# [        0, exp(-7/z)]])

# %%
Phi
# Out:
# Matrix([
# [exp((1 - exp(-u*z))/z),                        0],
# [                     0, exp(7*(1 - exp(-u*z))/z)]])

# %% [markdown]
# The final solution is $T^{-1}[\Psi]$ (we use $T$ to denote the total Gauge Transform that we applied to simplify the system)
#
# $T^{-1}$ is the Total_inverse that we just found above.

# %%
T_inverse_Psi = (Total * Psi + Derivative(Total, z).simplify() * z**k) * Total_inverse 
T_inverse_Psi = T_inverse_Psi.simplify()

# %%
T_inverse_Psi
# Out:
# Matrix([
# [                                                                                                                                            ((z*(z**2 + 36)*exp(7/z) + 36)*(-z**3 + 2*(z**3 - 36)*exp(z**2/72) + 72)*exp((z**3 + 36)/(36*z)) + (exp(z**2/72) - 2*exp(z**2/36))*(z**3*(z**3 + 108*z - 36)*exp(1/z) + 36*z**3 - 1296)*exp((z**3 + 504)/(72*z)))*exp(z**2/72 - (z**3 + 192)/(24*z))/1296,                                                                                                                                                                         z*(-2*z**4*exp(7/z) - z**3*exp(6/z) + z**3 - 36*z*exp(7/z) + 36*exp(6/z) - 36)*exp(z**2/72 - 7/z)/216],
# [-((exp(z**2/72) - 2*exp(z**2/36))*(18*z**3 - z*(18*z**3 - z**2*(108*z*(exp(z**2/72) - 1) + 54*z + (z**3 - 36)*exp(z**2/72)) + 36*(z**3 - 36)*(exp(z**2/72) - 1))*exp(1/z) + 36*(z**3 - 36)*(exp(z**2/72) - 1))*exp((z**3 + 504)/(72*z)) + (-z**3 + 2*(z**3 - 36)*exp(z**2/72) + 72)*(z**3*exp((z**3 + 504)/(72*z)) + 36*exp(z**2/72) - 18)*exp((z**3 + 36)/(36*z)))*exp(-(z**3 + 192)/(24*z))/(108*z), (-(z**3 - 36)*(z**3*exp((z**3 + 504)/(72*z)) + 36*exp(z**2/72) - 18) + (18*z**3 + z*(-18*z**3 + z**2*(-108*z*(1 - exp(z**2/72)) + 54*z + (z**3 - 36)*exp(z**2/72)) + 36*(1 - exp(z**2/72))*(z**3 - 36))*exp(1/z) - 36*(1 - exp(z**2/72))*(z**3 - 36))*exp(6/z))*exp(-7/z)/648]])

# %%
Final_Phi = get_phi_from_psi(T_inverse_Psi, k)
## This will take much long time to run.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 Final_Phi = get_phi_from_psi(T_inverse_Psi, k)
#
# File D:\Perturbation\Matrix_ODE\Stokes.py:34, in get_phi_from_psi(psi, k)
#      32 psi_end = psi.subs(z, S.target(u, z))
#      33 psi_start = psi.subs(z, S.source(u, z))
# ---> 34 prod = psi_end * Inverse(psi_start)
#      35 prod = prod.simplify()
#      36 return prod
#
# File ~\anaconda3\Lib\site-packages\sympy\core\decorators.py:105, in call_highest_priority.<locals>.priority_decorator.<locals>.binary_op_wrapper(self, other)
#     103         f = getattr(other, method_name, None)
#     104         if f is not None:
# --> 105             return f(self)
#     106 return func(self, other)
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\expressions\matexpr.py:28, in _sympifyit.<locals>.deco.<locals>.__sympifyit_wrapper(a, b)
#      26 try:
#      27     b = _sympify(b)
# ---> 28     return func(a, b)
#      29 except SympifyError:
#      30     return retval
#
# File ~\anaconda3\Lib\site-packages\sympy\core\decorators.py:106, in call_highest_priority.<locals>.priority_decorator.<locals>.binary_op_wrapper(self, other)
#     104         if f is not None:
#     105             return f(self)
# --> 106 return func(self, other)
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\expressions\matexpr.py:138, in MatrixExpr.__rmul__(self, other)
#     135 @_sympifyit('other', NotImplemented)
#     136 @call_highest_priority('__mul__')
#     137 def __rmul__(self, other):
# --> 138     return MatMul(other, self).doit()
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\expressions\matmul.py:192, in MatMul.doit(self, **hints)
#     190 deep = hints.get('deep', True)
#     191 if deep:
# --> 192     args = tuple(arg.doit(**hints) for arg in self.args)
#     193 else:
#     194     args = self.args
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\expressions\matmul.py:192, in <genexpr>(.0)
#     190 deep = hints.get('deep', True)
#     191 if deep:
# --> 192     args = tuple(arg.doit(**hints) for arg in self.args)
#     193 else:
#     194     args = self.args
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\expressions\inverse.py:78, in Inverse.doit(self, **hints)
#      75 if hints.get('deep', True):
#      76     arg = arg.doit(**hints)
# ---> 78 return arg.inverse()
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\expressions\matexpr.py:273, in MatrixExpr.inverse(self)
#     271 if self.is_square is False:
#     272     raise NonSquareMatrixError('Inverse of non-square matrix')
# --> 273 return self._eval_inverse()
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\dense.py:55, in DenseMatrix._eval_inverse(self, **kwargs)
#      54 def _eval_inverse(self, **kwargs):
# ---> 55     return self.inv(method=kwargs.get('method', 'GE'),
#      56                     iszerofunc=kwargs.get('iszerofunc', _iszero),
#      57                     try_block_diag=kwargs.get('try_block_diag', False))
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\matrixbase.py:5219, in MatrixBase.inv(self, method, iszerofunc, try_block_diag)
#    5218 def inv(self, method=None, iszerofunc=_iszero, try_block_diag=False):
# -> 5219     return _inv(self, method=method, iszerofunc=iszerofunc,
#    5220             try_block_diag=try_block_diag)
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\inverse.py:508, in _inv(M, method, iszerofunc, try_block_diag)
#     506     rv = _inv_DM(dM, cancel=False)
#     507 elif method == "GE":
# --> 508     rv = M.inverse_GE(iszerofunc=iszerofunc)
#     509 elif method == "LU":
#     510     rv = M.inverse_LU(iszerofunc=iszerofunc)
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\matrixbase.py:5204, in MatrixBase.inverse_GE(self, iszerofunc)
#    5203 def inverse_GE(self, iszerofunc=_iszero):
# -> 5204     return _inv_GE(self, iszerofunc=iszerofunc)
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\inverse.py:196, in _inv_GE(M, iszerofunc)
#     193     raise NonSquareMatrixError("A Matrix must be square to invert.")
#     195 big = Matrix.hstack(M.as_mutable(), Matrix.eye(M.rows))
# --> 196 red = big.rref(iszerofunc=iszerofunc, simplify=True)[0]
#     198 if any(iszerofunc(red[j, j]) for j in range(red.rows)):
#     199     raise NonInvertibleMatrixError("Matrix det == 0; not invertible.")
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\matrixbase.py:3141, in MatrixBase.rref(self, iszerofunc, simplify, pivots, normalize_last)
#    3139 def rref(self, iszerofunc=_iszero, simplify=False, pivots=True,
#    3140         normalize_last=True):
# -> 3141     return _rref(self, iszerofunc=iszerofunc, simplify=simplify,
#    3142         pivots=pivots, normalize_last=normalize_last)
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\reductions.py:381, in _rref(M, iszerofunc, simplify, pivots, normalize_last)
#     378     else:
#     379         simpfunc = _simplify
# --> 381     mat, pivot_cols, _ = _row_reduce(M, iszerofunc, simpfunc,
#     382             normalize_last, normalize=True, zero_above=True)
#     384 if pivots:
#     385     return mat, pivot_cols
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\reductions.py:127, in _row_reduce(M, iszerofunc, simpfunc, normalize_last, normalize, zero_above)
#     124 def _row_reduce(M, iszerofunc, simpfunc, normalize_last=True,
#     125                 normalize=True, zero_above=True):
# --> 127     mat, pivot_cols, swaps = _row_reduce_list(list(M), M.rows, M.cols, M.one,
#     128             iszerofunc, simpfunc, normalize_last=normalize_last,
#     129             normalize=normalize, zero_above=zero_above)
#     131     return M._new(M.rows, M.cols, mat), pivot_cols, swaps
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\reductions.py:118, in _row_reduce_list(mat, rows, cols, one, iszerofunc, simpfunc, normalize_last, normalize, zero_above)
#     116         mat[piv_i*cols + piv_j] = one
#     117         for p in range(piv_i*cols + piv_j + 1, (piv_i + 1)*cols):
# --> 118             mat[p] = isimp(mat[p] / pivot_val)
#     120 return mat, tuple(pivot_cols), tuple(swaps)
#
# File ~\anaconda3\Lib\site-packages\sympy\matrices\utilities.py:27, in _dotprodsimp(expr, withsimp)
#      25 """Wrapper for simplify.dotprodsimp to avoid circular imports."""
#      26 from sympy.simplify.simplify import dotprodsimp as dps
# ---> 27 return dps(expr, withsimp=withsimp)
#
# File ~\anaconda3\Lib\site-packages\sympy\simplify\simplify.py:2099, in dotprodsimp(expr, withsimp)
#    2096 expr2   = nonalg_subs_dummies(expr, dummies)
#    2098 if expr2 is expr or count_ops_alg(expr2)[0] >= 6: # check again after substitution
# -> 2099     expr3 = cancel(expr2)
#    2101     if expr3 != expr2:
#    2102         expr       = expr3.subs([(d, e) for e, d in dummies.items()])
#
# File ~\anaconda3\Lib\site-packages\sympy\polys\polytools.py:7163, in cancel(f, _signsimp, *gens, **args)
#    7161     if f.is_Number or isinstance(f, Relational) or not isinstance(f, Expr):
#    7162         return f
# -> 7163     f = factor_terms(f, radical=True)
#    7164     p, q = f.as_numer_denom()
#    7166 elif len(f) == 2:
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:1267, in factor_terms(expr, radical, clear, fraction, sign)
#    1265     return rv
#    1266 expr = sympify(expr)
# -> 1267 return do(expr)
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:1242, in factor_terms.<locals>.do(expr)
#    1240 cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1241 if p.is_Add:
# -> 1242     list_args = [do(a) for a in Add.make_args(p)]
#    1243     # get a common negative (if there) which gcd_terms does not remove
#    1244     if not any(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is None
#    1245                for a in list_args):
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:1242, in <listcomp>(.0)
#    1240 cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1241 if p.is_Add:
# -> 1242     list_args = [do(a) for a in Add.make_args(p)]
#    1243     # get a common negative (if there) which gcd_terms does not remove
#    1244     if not any(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is None
#    1245                for a in list_args):
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:1263, in factor_terms.<locals>.do(expr)
#    1257     p = gcd_terms(p,
#    1258         isprimitive=True,
#    1259         clear=clear,
#    1260         fraction=fraction).xreplace(special)
#    1261 elif p.args:
#    1262     p = p.func(
# -> 1263         *[do(a) for a in p.args])
#    1264 rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1265 return rv
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:1263, in <listcomp>(.0)
#    1257     p = gcd_terms(p,
#    1258         isprimitive=True,
#    1259         clear=clear,
#    1260         fraction=fraction).xreplace(special)
#    1261 elif p.args:
#    1262     p = p.func(
# -> 1263         *[do(a) for a in p.args])
#    1264 rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1265 return rv
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:1230, in factor_terms.<locals>.do(expr)
#    1227 if expr.is_Pow or expr.is_Function or \
#    1228         is_iterable or not hasattr(expr, 'args_cnc'):
#    1229     args = expr.args
# -> 1230     newargs = tuple([do(i) for i in args])
#    1231     if newargs == args:
#    1232         return expr
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:1230, in <listcomp>(.0)
#    1227 if expr.is_Pow or expr.is_Function or \
#    1228         is_iterable or not hasattr(expr, 'args_cnc'):
#    1229     args = expr.args
# -> 1230     newargs = tuple([do(i) for i in args])
#    1231     if newargs == args:
#    1232         return expr
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:1257, in factor_terms.<locals>.do(expr)
#    1255     # rebuild p not worrying about the order which gcd_terms will fix
#    1256     p = Add._from_args(list_args)
# -> 1257     p = gcd_terms(p,
#    1258         isprimitive=True,
#    1259         clear=clear,
#    1260         fraction=fraction).xreplace(special)
#    1261 elif p.args:
#    1262     p = p.func(
#    1263         *[do(a) for a in p.args])
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:1068, in gcd_terms(terms, isprimitive, clear, fraction)
#    1066     terms = sympify(terms)
#    1067 terms, reps = mask(terms)
# -> 1068 cont, numer, denom = _gcd_terms(terms, isprimitive, fraction)
#    1069 numer = numer.xreplace(reps)
#    1070 coeff, factors = cont.as_coeff_Mul()
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:953, in _gcd_terms(terms, isprimitive, fraction)
#     950     cont = cont.gcd(term)
#     952 for i, term in enumerate(terms):
# --> 953     terms[i] = term.quo(cont)
#     955 if fraction:
#     956     denom = terms[0].denom
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:868, in Term.quo(self, other)
#     867 def quo(self, other):  # Term
# --> 868     return self.mul(other.inv())
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:860, in Term.mul(self, other)
#     857 numer = self.numer.mul(other.numer)
#     858 denom = self.denom.mul(other.denom)
# --> 860 numer, denom = numer.normal(denom)
#     862 return Term(coeff, numer, denom)
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:554, in Factors.normal(self, other)
#     551             else:
#     552                 del other_factors[factor]
# --> 554 return Factors(self_factors), Factors(other_factors)
#
# File ~\anaconda3\Lib\site-packages\sympy\core\exprtools.py:324, in Factors.__init__(self, factors)
#     322 if isinstance(factors, Factors):
#     323     factors = factors.factors.copy()
# --> 324 elif factors in (None, S.One):
#     325     factors = {}
#     326 elif factors is S.Zero or factors == 0:
#
# File ~\anaconda3\Lib\site-packages\sympy\core\numbers.py:1939, in Integer.__eq__(self, other)
#    1937 elif isinstance(other, Integer):
#    1938     return (self.p == other.p)
# -> 1939 return Rational.__eq__(self, other)
#
# File ~\anaconda3\Lib\site-packages\sympy\core\numbers.py:1593, in Rational.__eq__(self, other)
#    1591 def __eq__(self, other):
#    1592     try:
# -> 1593         other = _sympify(other)
#    1594     except SympifyError:
#    1595         return NotImplemented
#
# File ~\anaconda3\Lib\site-packages\sympy\core\sympify.py:514, in _sympify(a)
#     488 def _sympify(a):
#     489     """
#     490     Short version of :func:`~.sympify` for internal usage for ``__add__`` and
#     491     ``__eq__`` methods where it is ok to allow some things (like Python
#    (...)
#     512
#     513     """
# --> 514     return sympify(a, strict=True)
#
# File ~\anaconda3\Lib\site-packages\sympy\core\sympify.py:396, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     394         conv = _sympy_converter.get(superclass)
#     395     if conv is not None:
# --> 396         return conv(a)
#     398 if cls is type(None):
#     399     if strict:
#
# File ~\anaconda3\Lib\site-packages\sympy\core\containers.py:332, in <lambda>(d)
#     329     __hash__ : Callable[[Basic], Any] = Basic.__hash__
#     331 # this handles dict, defaultdict, OrderedDict
# --> 332 _sympy_converter[dict] = lambda d: Dict(*d.items())
#     334 class OrderedSet(MutableSet):
#     335     def __init__(self, iterable=None):
#
# File ~\anaconda3\Lib\site-packages\sympy\core\containers.py:263, in Dict.__new__(cls, *args)
#     261     raise TypeError('Pass Dict args as Dict((k1, v1), ...) or Dict({k1: v1, ...})')
#     262 elements = frozenset(items)
# --> 263 obj = Basic.__new__(cls, *ordered(items))
#     264 obj.elements = elements
#     265 obj._dict = dict(items)  # In case Tuple decides it wants to sympify
#
# File ~\anaconda3\Lib\site-packages\sympy\core\sorting.py:312, in ordered(seq, keys, default, warn)
#     309         if len(u) > 1:
#     310             raise ValueError(
#     311                 'not enough keys to break ties: %s' % u)
# --> 312 yield from value
#
# File ~\anaconda3\Lib\site-packages\sympy\core\sorting.py:294, in ordered(seq, keys, default, warn)
#     292         keys = []
#     293     for a in seq:
# --> 294         d[f(a)].append(a)
#     295 else:
#     296     if not default:
#
# File ~\anaconda3\Lib\site-packages\sympy\core\sorting.py:193, in _nodes(e)
#     190     if isinstance(e, Derivative):
#     191         return _nodes(e.expr) + sum(i[1] if i[1].is_Number else
#     192             _nodes(i[1]) for i in e.variable_count)
# --> 193     return _node_count(e)
#     194 elif iterable(e):
#     195     return 1 + sum(_nodes(ei) for ei in e)
#
# File ~\anaconda3\Lib\site-packages\sympy\core\sorting.py:176, in _node_count(e)
#     174 if e.is_Float:
#     175     return 0.5
# --> 176 return 1 + sum(map(_node_count, e.args))
#
# File ~\anaconda3\Lib\site-packages\sympy\core\sorting.py:176, in _node_count(e)
#     174 if e.is_Float:
#     175     return 0.5
# --> 176 return 1 + sum(map(_node_count, e.args))
#
# KeyboardInterrupt:

# %%
Final_Phi
